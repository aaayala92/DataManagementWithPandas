# %% [markdown]
# # Data Management with Pandas
#
# ### Lesson 1
#
# Its all done in google collab, look for:
# https://colab.research.google.com/drive/1SM4WSqYI7FoLhEkU4M3P4iN5bf_FDGZA?usp=sharing

# %%
#Importing Pandas library

import pandas as pd

# %% [markdown]
# Python Datatypes
#
# Pandas has DataFrame
#
# Its tabular data, you can modify it. Its like an excel

# %%
#importing a csv file

df1 = pd.read_csv("stores.csv")

# %%
df1
# Out:
#                          Name            Address        City State  \
# 0             SCENTSIBILITIES        750 MAIN ST    BOYLSTON    MA
# 1                 MODEL DAIRY        469 MAIN ST    BOYLSTON    MA
# 2              DUNKIN' DONUTS  270 SHREWSBURY ST    BOYLSTON    MA
# 3              MOBILE STATION       22 MAPLE AVE  SHREWSBURY    MA
# 4       HORTON'S SUPER MARKET     117 CLINTON ST  SHREWSBURY    MA
# ...                       ...                ...         ...   ...
# 4639  STORE AT SANDY POND INC      832 BOURNE RD    PLYMOUTH    MA
# 4640                   MARKET      6 PURCHASE ST    PLYMOUTH    MA
# 4641      TEDESCHI FOOD SHOPS      2302 STATE RD    PLYMOUTH    MA
# 4642           DUNKIN' DONUTS      2300 STATE RD    PLYMOUTH    MA
# 4643       SHAW'S SUPERMARKET      2260 STATE RD    PLYMOUTH    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 0     Massachusetts  1505    115           1      A
# 1     Massachusetts  1505    115           1      A
# 2     Massachusetts  1505    840          15      C
# 3     Massachusetts  1545    896           4      A
# 4     Massachusetts  1545    494           2      A
# ...             ...   ...    ...         ...    ...
# 4639  Massachusetts  2360  69440         310      G
# 4640  Massachusetts  2360    988           4      A
# 4641  Massachusetts  2360    896           4      A
# 4642  Massachusetts  2360    280           5      B
# 4643  Massachusetts  2360  49400         200      F
#
# [4644 rows x 9 columns]

# %%
#importing an excel file

#I dont now why I had to install this: pip install openpyxl

df2 = pd.read_excel("stores.xlsx")

# %%
df2
# Out:
#                          Name            Address        City State  \
# 0             SCENTSIBILITIES        750 MAIN ST    BOYLSTON    MA
# 1                 MODEL DAIRY        469 MAIN ST    BOYLSTON    MA
# 2              DUNKIN' DONUTS  270 SHREWSBURY ST    BOYLSTON    MA
# 3              MOBILE STATION       22 MAPLE AVE  SHREWSBURY    MA
# 4       HORTON'S SUPER MARKET     117 CLINTON ST  SHREWSBURY    MA
# ...                       ...                ...         ...   ...
# 4639  STORE AT SANDY POND INC      832 BOURNE RD    PLYMOUTH    MA
# 4640                   MARKET      6 PURCHASE ST    PLYMOUTH    MA
# 4641      TEDESCHI FOOD SHOPS      2302 STATE RD    PLYMOUTH    MA
# 4642           DUNKIN' DONUTS      2300 STATE RD    PLYMOUTH    MA
# 4643       SHAW'S SUPERMARKET      2260 STATE RD    PLYMOUTH    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 0     Massachusetts  1505    115           1      A
# 1     Massachusetts  1505    115           1      A
# 2     Massachusetts  1505    840          15      C
# 3     Massachusetts  1545    896           4      A
# 4     Massachusetts  1545    494           2      A
# ...             ...   ...    ...         ...    ...
# 4639  Massachusetts  2360  69440         310      G
# 4640  Massachusetts  2360    988           4      A
# 4641  Massachusetts  2360    896           4      A
# 4642  Massachusetts  2360    280           5      B
# 4643  Massachusetts  2360  49400         200      F
#
# [4644 rows x 9 columns]

# %% [markdown]
# ### Data Inspection

# %%
#look at top rows
df1.head() #starts with 5 by default
# Out:
#                     Name            Address        City State     State_name  \
# 0        SCENTSIBILITIES        750 MAIN ST    BOYLSTON    MA  Massachusetts
# 1            MODEL DAIRY        469 MAIN ST    BOYLSTON    MA  Massachusetts
# 2         DUNKIN' DONUTS  270 SHREWSBURY ST    BOYLSTON    MA  Massachusetts
# 3         MOBILE STATION       22 MAPLE AVE  SHREWSBURY    MA  Massachusetts
# 4  HORTON'S SUPER MARKET     117 CLINTON ST  SHREWSBURY    MA  Massachusetts
#
#     Zip  Sales  Number_emp Empsiz
# 0  1505    115           1      A
# 1  1505    115           1      A
# 2  1505    840          15      C
# 3  1545    896           4      A
# 4  1545    494           2      A

# %%
df1.head(10)
# Out:
#                     Name             Address        City State     State_name  \
# 0        SCENTSIBILITIES         750 MAIN ST    BOYLSTON    MA  Massachusetts
# 1            MODEL DAIRY         469 MAIN ST    BOYLSTON    MA  Massachusetts
# 2         DUNKIN' DONUTS   270 SHREWSBURY ST    BOYLSTON    MA  Massachusetts
# 3         MOBILE STATION        22 MAPLE AVE  SHREWSBURY    MA  Massachusetts
# 4  HORTON'S SUPER MARKET      117 CLINTON ST  SHREWSBURY    MA  Massachusetts
# 5               7-ELEVEN        38 MAPLE AVE  SHREWSBURY    MA  Massachusetts
# 6         DUNKIN' DONUTS        36 MAPLE AVE  SHREWSBURY    MA  Massachusetts
# 7              DONUT INN         574 MAIN ST  SHREWSBURY    MA  Massachusetts
# 8     SHAW'S SUPERMARKET      50 BOSTON TPKE  SHREWSBURY    MA  Massachusetts
# 9         VITAMIN SHOPPE  77 BOSTON TPKE # A  SHREWSBURY    MA  Massachusetts
#
#     Zip  Sales  Number_emp Empsiz
# 0  1505    115           1      A
# 1  1505    115           1      A
# 2  1505    840          15      C
# 3  1545    896           4      A
# 4  1545    494           2      A
# 5  1545   1344           6      B
# 6  1545   1568          28      D
# 7  1545    112           2      A
# 8  1545  34580         140      F
# 9  1545    604           4      A

# %%
#look at botton rows
df1.tail()
# Out:
#                          Name        Address      City State     State_name  \
# 4639  STORE AT SANDY POND INC  832 BOURNE RD  PLYMOUTH    MA  Massachusetts
# 4640                   MARKET  6 PURCHASE ST  PLYMOUTH    MA  Massachusetts
# 4641      TEDESCHI FOOD SHOPS  2302 STATE RD  PLYMOUTH    MA  Massachusetts
# 4642           DUNKIN' DONUTS  2300 STATE RD  PLYMOUTH    MA  Massachusetts
# 4643       SHAW'S SUPERMARKET  2260 STATE RD  PLYMOUTH    MA  Massachusetts
#
#        Zip  Sales  Number_emp Empsiz
# 4639  2360  69440         310      G
# 4640  2360    988           4      A
# 4641  2360    896           4      A
# 4642  2360    280           5      B
# 4643  2360  49400         200      F

# %%
#get a sample of the data
df1.sample(4) #4 random rows
# Out:
#                      Name              Address           City State  \
# 765     SUPER STOP & SHOP        6 THATCHER RD     GLOUCESTER    MA
# 3431         TRADER JOE'S  300 ANDOVER ST # 15        PEABODY    MA
# 1911      EVELYN'S MARKET        298 CENTRE ST  JAMAICA PLAIN    MA
# 3905  TEDESCHI FOOD SHOPS        325 W MAIN ST         NORTON    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 765   Massachusetts  1930  30875         125      F
# 3431  Massachusetts  1960   9880          40      D
# 1911  Massachusetts  2130    247           1      A
# 3905  Massachusetts  2766   1344           6      B

# %%
#Get the shape of the data
df1.shape #the result is a tuple, it is not a function (total rows, total columns)
# Out:
# (4644, 9)

# %%
#you can assign this to variables
n,m=df1.shape

print('I have', n, 'rows and', m ,'columns')
# Out:
# I have 4644 rows and 9 columns

# %%
#information of the dataset
df1.info()  #here you could see the data type, object is similar to strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4644 entries, 0 to 4643
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4644 non-null   object
#  1   Address     4609 non-null   object
#  2   City        4644 non-null   object
#  3   State       4644 non-null   object
#  4   State_name  4644 non-null   object
#  5   Zip         4644 non-null   int64
#  6   Sales       4644 non-null   int64
#  7   Number_emp  4644 non-null   int64
#  8   Empsiz      4644 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 326.7+ KB

# %%
#how to combine multiple files
to_concat = [df1,df2] #it needs a list of dataframes

data = pd.concat(to_concat, ignore_index=True)

data

#we could have do it as pd.concat([df1,df2])
#if we dont ignore index we get a repeated index
#if you make the mistake go with data.reset_index(inplace=True)
# Out:
#                          Name            Address        City State  \
# 0             SCENTSIBILITIES        750 MAIN ST    BOYLSTON    MA
# 1                 MODEL DAIRY        469 MAIN ST    BOYLSTON    MA
# 2              DUNKIN' DONUTS  270 SHREWSBURY ST    BOYLSTON    MA
# 3              MOBILE STATION       22 MAPLE AVE  SHREWSBURY    MA
# 4       HORTON'S SUPER MARKET     117 CLINTON ST  SHREWSBURY    MA
# ...                       ...                ...         ...   ...
# 9283  STORE AT SANDY POND INC      832 BOURNE RD    PLYMOUTH    MA
# 9284                   MARKET      6 PURCHASE ST    PLYMOUTH    MA
# 9285      TEDESCHI FOOD SHOPS      2302 STATE RD    PLYMOUTH    MA
# 9286           DUNKIN' DONUTS      2300 STATE RD    PLYMOUTH    MA
# 9287       SHAW'S SUPERMARKET      2260 STATE RD    PLYMOUTH    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 0     Massachusetts  1505    115           1      A
# 1     Massachusetts  1505    115           1      A
# 2     Massachusetts  1505    840          15      C
# 3     Massachusetts  1545    896           4      A
# 4     Massachusetts  1545    494           2      A
# ...             ...   ...    ...         ...    ...
# 9283  Massachusetts  2360  69440         310      G
# 9284  Massachusetts  2360    988           4      A
# 9285  Massachusetts  2360    896           4      A
# 9286  Massachusetts  2360    280           5      B
# 9287  Massachusetts  2360  49400         200      F
#
# [9288 rows x 9 columns]

# %%
#how to write the data to a file
data.to_excel('all_stores.xlsx', index=False) #save file without the index so that you dont have a redundant information

# %% [markdown]
# ## In-Class Activity 1

# %% [markdown]
# ### In-class activity 1
# ### Use the CO2_emissions dataset to perform the following:
#
#
# 1. Read the data contained in file CO2_emissions_2016.csv in a DataFrame with the name df_2016. Also, read the data from CO2_emissions_2017.xlsx with the name df_2017.
# 2. Display the first 10 rows of df_2016 and the last 20 rows of df_2017.
# 3. How many rows and columns are in df_2016 and df_2017? Display the answer.
# 4.	Concatenate df_2016 and df_2017 into a single DataFrame named df.
# 5.	Write the resulting DataFrame df to an Excel file. Do not include the index in the file.
#
# ### Please, use cells below to write and execute your code. Feel free to add additional cells.

# %%
df_2016 = pd.read_csv('CO2_emissions_2016.csv')
df_2017 = pd.read_excel('CO2_emissions_2017.xlsx')

# %%
df_2016.head(10)
# Out:
#    Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions
# 0       14620  2016      1    1        47      10         0.0329
# 1         693  2016      1    2        63       9         0.0504
# 2         695  2016      1    2        53       9         0.0424
# 3         705  2016      1    2        58       7         0.0638
# 4         811  2016      1    2        64       5         0.0960
# 5         833  2016      1    2        60       9         0.0480
# 6         847  2016      1    2        67       9         0.0536
# 7         863  2016      1    2        44       5         0.0660
# 8         868  2016      1    2        68       9         0.0544
# 9         868  2016      1    2        43      10         0.0301

# %%
df_2017.tail(20)
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions
# 23216       14645  2017      3   31        63       8         0.0567
# 23217       14645  2017      3   31        57       9         0.0456
# 23218       14647  2017      3   31        66      10         0.0462
# 23219       14647  2017      3   31        53      10         0.0371
# 23220       14647  2017      3   31        58       7         0.0638
# 23221       14648  2017      3   31        71       9         0.0568
# 23222       14649  2017      3   31        68       7         0.0748
# 23223       14649  2017      3   31        44       8         0.0396
# 23224       14651  2017      3   31        59       8         0.0531
# 23225       14654  2017      3   31        75       6         0.0975
# 23226       14698  2017      3   31        36       6         0.0468
# 23227       14709  2017      3   31        39       8         0.0351
# 23228       14709  2017      3   31        51       9         0.0408
# 23229       14710  2017      3   31        57       9         0.0456
# 23230       14710  2017      3   31        67       5         0.1005
# 23231       14711  2017      3   31        58       8         0.0522
# 23232       14750  2017      3   31        68       6         0.0884
# 23233       14772  2017      3   31        62       5         0.0930
# 23234       14778  2017      3   31        73      10         0.0511
# 23235       14779  2017      3   31        66       5         0.0990

# %%
df_2016.shape
# Out:
# (25946, 7)

# %%
df_2017.shape
# Out:
# (23236, 7)

# %%
df = pd.concat([df_2016,df_2017])

# %%
df.to_excel('CO2_emmisions.xlsx', index=False)

# %% [markdown]
# ## Class Continues

# %%
#Selecting a column
df1['Sales'] #this gives a series
df1[['Sales']] #here you return a df
# Out:
#       Sales
# 0       115
# 1       115
# 2       840
# 3       896
# 4       494
# ...     ...
# 4639  69440
# 4640    988
# 4641    896
# 4642    280
# 4643  49400
#
# [4644 rows x 1 columns]

# %%
#Selecting several columns
df1[['Sales','Address']]
# Out:
#       Sales            Address
# 0       115        750 MAIN ST
# 1       115        469 MAIN ST
# 2       840  270 SHREWSBURY ST
# 3       896       22 MAPLE AVE
# 4       494     117 CLINTON ST
# ...     ...                ...
# 4639  69440      832 BOURNE RD
# 4640    988      6 PURCHASE ST
# 4641    896      2302 STATE RD
# 4642    280      2300 STATE RD
# 4643  49400      2260 STATE RD
#
# [4644 rows x 2 columns]

# %%
#select one row
df1.iloc[1] #this is first number, loc checks for index
# Out:
# Name            MODEL DAIRY
# Address         469 MAIN ST
# City               BOYLSTON
# State                    MA
# State_name    Massachusetts
# Zip                    1505
# Sales                   115
# Number_emp                1
# Empsiz                    A
# Name: 1, dtype: object

# %%
# look for a slice
df1.loc[2:11]
# Out:
#                      Name             Address        City State  \
# 2          DUNKIN' DONUTS   270 SHREWSBURY ST    BOYLSTON    MA
# 3          MOBILE STATION        22 MAPLE AVE  SHREWSBURY    MA
# 4   HORTON'S SUPER MARKET      117 CLINTON ST  SHREWSBURY    MA
# 5                7-ELEVEN        38 MAPLE AVE  SHREWSBURY    MA
# 6          DUNKIN' DONUTS        36 MAPLE AVE  SHREWSBURY    MA
# 7               DONUT INN         574 MAIN ST  SHREWSBURY    MA
# 8      SHAW'S SUPERMARKET      50 BOSTON TPKE  SHREWSBURY    MA
# 9          VITAMIN SHOPPE  77 BOSTON TPKE # A  SHREWSBURY    MA
# 10           TRADER JOE'S      77 BOSTON TPKE  SHREWSBURY    MA
# 11     INDIA FOOD & GIFTS     264 BOSTON TPKE  SHREWSBURY    MA
#
#        State_name   Zip  Sales  Number_emp Empsiz
# 2   Massachusetts  1505    840          15      C
# 3   Massachusetts  1545    896           4      A
# 4   Massachusetts  1545    494           2      A
# 5   Massachusetts  1545   1344           6      B
# 6   Massachusetts  1545   1568          28      D
# 7   Massachusetts  1545    112           2      A
# 8   Massachusetts  1545  34580         140      F
# 9   Massachusetts  1545    604           4      A
# 10  Massachusetts  1545  14820          60      E
# 11  Massachusetts  1545    247           1      A

# %%
#what if we want 3rd row and 3rd column
df1.iloc[2,2]
# Out:
# 'BOYLSTON'

# %%
#filtering data
df1[df1['Sales']>5000]
# Out:
#                          Name                        Address        City  \
# 8          SHAW'S SUPERMARKET                 50 BOSTON TPKE  SHREWSBURY
# 10               TRADER JOE'S                 77 BOSTON TPKE  SHREWSBURY
# 17    STOP & SHOP SUPERMARKET                539 BOSTON TPKE  SHREWSBURY
# 20              PRICE CHOPPER                  380 MAPLE AVE  SHREWSBURY
# 41              MARKET BASKET          160 LITTLETON RD # 16    WESTFORD
# ...                       ...                            ...         ...
# 4608       SHAW'S SUPERMARKET  739 CHIEF JUSTICE CUSHING HWY    COHASSET
# 4617        BRANT ROCK MARKET                     24 DYKE RD  MARSHFIELD
# 4619              STAR MARKET                     20 SNOW RD  MARSHFIELD
# 4639  STORE AT SANDY POND INC                  832 BOURNE RD    PLYMOUTH
# 4643       SHAW'S SUPERMARKET                  2260 STATE RD    PLYMOUTH
#
#      State     State_name   Zip  Sales  Number_emp Empsiz
# 8       MA  Massachusetts  1545  34580         140      F
# 10      MA  Massachusetts  1545  14820          60      E
# 17      MA  Massachusetts  1545  24700         100      F
# 20      MA  Massachusetts  1545  34580         140      F
# 41      MA  Massachusetts  1886   6175          25      D
# ...    ...            ...   ...    ...         ...    ...
# 4608    MA  Massachusetts  2025  30875         125      F
# 4617    MA  Massachusetts  2050   7410          30      D
# 4619    MA  Massachusetts  2050  24700         100      F
# 4639    MA  Massachusetts  2360  69440         310      G
# 4643    MA  Massachusetts  2360  49400         200      F
#
# [278 rows x 9 columns]

# %%
#multiple conditions
df1[(df1['Sales']>5000) & (df1['Number_emp'] < 100)]  #In pandas we use & for and, | for or
# Out:
#                                 Name                Address        City State  \
# 10                      TRADER JOE'S         77 BOSTON TPKE  SHREWSBURY    MA
# 41                     MARKET BASKET  160 LITTLETON RD # 16    WESTFORD    MA
# 66    HANNAFORD SUPERMARKET & PHRMCY  22 FITCHBURG RD RT 2A        AYER    MA
# 74             DONELAN'S SUPERMARKET            250 MAIN ST      GROTON    MA
# 92                      TRADER JOE'S   440 MIDDLESEX RD # 4   TYNGSBORO    MA
# ...                              ...                    ...         ...   ...
# 4576                     LOBSTER HUT          25 TOWN WHARF    PLYMOUTH    MA
# 4577                  WOOD'S SEAFOOD           15 TOWN PIER    PLYMOUTH    MA
# 4586                  VILLAGE MARKET            71 FRONT ST    SCITUATE    MA
# 4601                      ROCHE BROS           605 PLAIN ST  MARSHFIELD    MA
# 4617               BRANT ROCK MARKET             24 DYKE RD  MARSHFIELD    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 10    Massachusetts  1545  14820          60      E
# 41    Massachusetts  1886   6175          25      D
# 66    Massachusetts  1432  16055          65      E
# 74    Massachusetts  1450   7410          30      D
# 92    Massachusetts  1879   8645          35      D
# ...             ...   ...    ...         ...    ...
# 4576  Massachusetts  2360  10395          45      D
# 4577  Massachusetts  2360   5775          25      D
# 4586  Massachusetts  2066  17290          70      E
# 4601  Massachusetts  2050  17290          70      E
# 4617  Massachusetts  2050   7410          30      D
#
# [104 rows x 9 columns]

# %%
#You can also use the .isin()
places = ['CAMBRIDGE','BOSTON']
df1[df1['City'].isin(places)]
# Out:
#                           Name                    Address       City State  \
# 1732           PEPPERIDGE FARM            87 BLANCHARD RD  CAMBRIDGE    MA
# 1733       SHAKLEE DISTRIBUTOR            97 BLANCHARD RD  CAMBRIDGE    MA
# 1793   BOSTON CHINESE MEDICINE        8 WHITTIER PL # 19C     BOSTON    MA
# 1797        SUPER EIGHTY EIGHT      1095 COMMONWEALTH AVE     BOSTON    MA
# 1798        SHAW'S SUPERMARKET  1065 COMMONWEALTH AVE # 2     BOSTON    MA
# ...                        ...                        ...        ...   ...
# 3771          L & D MARKET INC            121 MERIDIAN ST     BOSTON    MA
# 3772         BENI'S RESTAURANT            145 MERIDIAN ST     BOSTON    MA
# 3780             LUCHOS MARKET             42 MAVERICK ST     BOSTON    MA
# 3782  OFF THE BOAT SEAFOOD INC               26 PORTER ST     BOSTON    MA
# 3784    MAVERICK STREET MARKET            205 MAVERICK ST     BOSTON    MA
#
#          State_name   Zip  Sales  Number_emp Empsiz
# 1732  Massachusetts  2138    355           5      B
# 1733  Massachusetts  2138    302           2      A
# 1793  Massachusetts  2114    115           1      A
# 1797  Massachusetts  2215    988           4      A
# 1798  Massachusetts  2215  37050         150      F
# ...             ...   ...    ...         ...    ...
# 3771  Massachusetts  2128    741           3      A
# 3772  Massachusetts  2128    494           2      A
# 3780  Massachusetts  2128    741           3      A
# 3782  Massachusetts  2128    231           1      A
# 3784  Massachusetts  2128    741           3      A
#
# [438 rows x 9 columns]

# %%
#Adding Columns
df1['Sales_per_emp'] = df1['Sales']/df1['Number_emp']

# %%
df1.columns
# Out:
# Index(['Name', 'Address', 'City', 'State', 'State_name', 'Zip', 'Sales',
#        'Number_emp', 'Empsiz', 'Sales_per_emp'],
#       dtype='object')

# %%
#delete columns

#one way is to create a new one with the columns you do want
new = df1[['Name','Address']]
print(new)

#another way
del df1['Empsiz']
print(df1)

#always create a copy
backup = df1.copy()
# Out:
#                          Name            Address
# 0             SCENTSIBILITIES        750 MAIN ST
# 1                 MODEL DAIRY        469 MAIN ST
# 2              DUNKIN' DONUTS  270 SHREWSBURY ST
# 3              MOBILE STATION       22 MAPLE AVE
# 4       HORTON'S SUPER MARKET     117 CLINTON ST
# ...                       ...                ...
# 4639  STORE AT SANDY POND INC      832 BOURNE RD
# 4640                   MARKET      6 PURCHASE ST
# 4641      TEDESCHI FOOD SHOPS      2302 STATE RD
# 4642           DUNKIN' DONUTS      2300 STATE RD
# 4643       SHAW'S SUPERMARKET      2260 STATE RD
#
# [4644 rows x 2 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Empsiz'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\artur\OneDrive\Documentos\MIT SCM\SCM250\Data_Management_With_Pandas\DataManagementWithPandas\Lesson1_pandas.ipynb Cell 38 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/artur/OneDrive/Documentos/MIT%20SCM/SCM250/Data_Management_With_Pandas/DataManagementWithPandas/Lesson1_pandas.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a> print(new)
#       <a href='vscode-notebook-cell:/c%3A/Users/artur/OneDrive/Documentos/MIT%20SCM/SCM250/Data_Management_With_Pandas/DataManagementWithPandas/Lesson1_pandas.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a> #another way
# ----> <a href='vscode-notebook-cell:/c%3A/Users/artur/OneDrive/Documentos/MIT%20SCM/SCM250/Data_Management_With_Pandas/DataManagementWithPandas/Lesson1_pandas.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a> del df1['Empsiz']
#       <a href='vscode-notebook-cell:/c%3A/Users/artur/OneDrive/Documentos/MIT%20SCM/SCM250/Data_Management_With_Pandas/DataManagementWithPandas/Lesson1_pandas.ipynb#X56sZmlsZQ%3D%3D?line=8'>9</a> print(df1)
#      <a href='vscode-notebook-cell:/c%3A/Users/artur/OneDrive/Documentos/MIT%20SCM/SCM250/Data_Management_With_Pandas/DataManagementWithPandas/Lesson1_pandas.ipynb#X56sZmlsZQ%3D%3D?line=10'>11</a> #always create a copy
#
# File c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4048, in NDFrame.__delitem__(self, key)
#    4043             deleted = True
#    4044 if not deleted:
#    4045     # If the above loop ran and didn't delete anything because
#    4046     # there was no match, this call should raise the appropriate
#    4047     # exception:
# -> 4048     loc = self.axes[-1].get_loc(key)
#    4049     self._mgr = self._mgr.idelete(loc)
#    4051 # delete from the caches
#
# File c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Empsiz'

# %%
#to delete more than one column
df2.drop(columns=['Empsiz','State'], inplace = True) #watchout because you need to assign this a name to be permanent or use inplace = True
# Out:
#                          Name            Address        City     State_name  \
# 0             SCENTSIBILITIES        750 MAIN ST    BOYLSTON  Massachusetts
# 1                 MODEL DAIRY        469 MAIN ST    BOYLSTON  Massachusetts
# 2              DUNKIN' DONUTS  270 SHREWSBURY ST    BOYLSTON  Massachusetts
# 3              MOBILE STATION       22 MAPLE AVE  SHREWSBURY  Massachusetts
# 4       HORTON'S SUPER MARKET     117 CLINTON ST  SHREWSBURY  Massachusetts
# ...                       ...                ...         ...            ...
# 4639  STORE AT SANDY POND INC      832 BOURNE RD    PLYMOUTH  Massachusetts
# 4640                   MARKET      6 PURCHASE ST    PLYMOUTH  Massachusetts
# 4641      TEDESCHI FOOD SHOPS      2302 STATE RD    PLYMOUTH  Massachusetts
# 4642           DUNKIN' DONUTS      2300 STATE RD    PLYMOUTH  Massachusetts
# 4643       SHAW'S SUPERMARKET      2260 STATE RD    PLYMOUTH  Massachusetts
#
#        Zip  Sales  Number_emp
# 0     1505    115           1
# 1     1505    115           1
# 2     1505    840          15
# 3     1545    896           4
# 4     1545    494           2
# ...    ...    ...         ...
# 4639  2360  69440         310
# 4640  2360    988           4
# 4641  2360    896           4
# 4642  2360    280           5
# 4643  2360  49400         200
#
# [4644 rows x 7 columns]

# %% [markdown]
# ### In-class activity 2
# ### Use the resulting DataFrame from previous activity to perform the following:
#
# 1.   Display the seventh row of DataFrame df.
# 2.   Create a new column called CO2_per_day to calculate the daily CO2 emissions (CO2_per_day = CO2_emissions x Distance x Weight).
# 3. Create a new DataFrame named daily_emissions that contains columns Vehicle_ID, Year, Month, Day, and CO2_per_day from df.
# 4. Create a new DataFrame called low_emissions with only vehicles whose daily emissions are less than 10 Kg by filtering daily_emissions.
# 5. Display (filter) all observations from vehicle IDs 1635, 1723, and 14444 in DataFrame low_emissions.
#
#
# ### Please, use cells below to write and execute your code. Feel free to add additional cells.

# %%
# write your code for in-class activity 2 here 

df.iloc[7]
# Out:
# Vehicle_ID        863.000
# Year             2016.000
# Month               1.000
# Day                 2.000
# Distance           44.000
# Weight              5.000
# CO2_emissions       0.066
# CO2_per_day        14.520
# Name: 7, dtype: float64

# %%
df['CO2_per_day']=df['CO2_emissions']*df['Distance']*df['Weight']

df.columns
# Out:
# Index(['Vehicle_ID', 'Year', 'Month', 'Day', 'Distance', 'Weight',
#        'CO2_emissions', 'CO2_per_day'],
#       dtype='object')

# %%
daily_emissions = df[['Vehicle_ID','Year','Month','Day','CO2_per_day']]
daily_emissions
# Out:
#        Vehicle_ID  Year  Month  Day  CO2_per_day
# 0           14620  2016      1    1      15.4630
# 1             693  2016      1    2      28.5768
# 2             695  2016      1    2      20.2248
# 3             705  2016      1    2      25.9028
# 4             811  2016      1    2      30.7200
# ...           ...   ...    ...  ...          ...
# 23231       14711  2017      3   31      24.2208
# 23232       14750  2017      3   31      36.0672
# 23233       14772  2017      3   31      28.8300
# 23234       14778  2017      3   31      37.3030
# 23235       14779  2017      3   31      32.6700
#
# [49182 rows x 5 columns]

# %%
low_emissions = df[df['CO2_per_day']<10]
low_emissions
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions  \
# 206          1635  2016      1    2        31      10         0.0217
# 260          1761  2016      1    2        35      10         0.0245
# 274          1792  2016      1    2        27       5         0.0405
# 352         14623  2016      1    2        29       9         0.0232
# 406          1223  2016      1    3        37       8         0.0333
# ...           ...   ...    ...  ...       ...     ...            ...
# 22862        1793  2017      3   30        37      10         0.0259
# 23010        1327  2017      3   31        29      10         0.0203
# 23091        1619  2017      3   31        35       9         0.0280
# 23188       14473  2017      3   31        32       5         0.0480
# 23201       14563  2017      3   31        36       7         0.0396
#
#        CO2_per_day
# 206         6.7270
# 260         8.5750
# 274         5.4675
# 352         6.0552
# 406         9.8568
# ...            ...
# 22862       9.5830
# 23010       5.8870
# 23091       8.8200
# 23188       7.6800
# 23201       9.9792
#
# [497 rows x 8 columns]

# %%
low_emissions[low_emissions['Vehicle_ID'].isin([1635, 1723,14444])]
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions  \
# 206          1635  2016      1    2        31      10         0.0217
# 865          1723  2016      1    4        31       7         0.0341
# 23360       14444  2016      3   19        37      10         0.0259
# 4603         1723  2017      1   18        35       8         0.0315
# 10786        1723  2017      2   10        37       9         0.0296
# 12977       14444  2017      2   18        30       9         0.0240
#
#        CO2_per_day
# 206         6.7270
# 865         7.3997
# 23360       9.5830
# 4603        8.8200
# 10786       9.8568
# 12977       6.4800

# %% [markdown]
# ## Class Continues
#
# Sorting values

# %%
df2.sort_values(by = 'Sales') #by default it is in ascending order
# Out:
#                             Name                    Address          City  \
# 1063         HONEY DEW ASSOC INC           2 TAUNTON ST # 3    PLAINVILLE
# 1504                  OMNI FOODS           21 CENTER ST # 2        WESTON
# 1346  DONELAN'S SUPERMARKETS INC               236 GREAT RD     LITTLETON
# 3647               AHOLD USA INC            1385 HANCOCK ST        QUINCY
# 4403     TEDESCHI FOOD SHOPS INC               14 HOWARD ST      ROCKLAND
# ...                          ...                        ...           ...
# 1522                  ROCHE BROS           150 W CENTRAL ST        NATICK
# 1006               MARKET BASKET           274 HARTFORD AVE    BELLINGHAM
# 2494           SUPER STOP & SHOP          8 ALLSTATE RD # B    DORCHESTER
# 4147                  ROCHE BROS  20 ROCHE BROTHERS WAY # 1  NORTH EASTON
# 3812    JOHNNIE'S FOODMASTER INC       100 EVERETT AVE # 12       CHELSEA
#
#      State     State_name   Zip   Sales  Number_emp Empsiz
# 1063    MA  Massachusetts  2762       0          15      C
# 1504    MA  Massachusetts  2493       0          49      D
# 1346    MA  Massachusetts  1460       0         100      F
# 3647    MA  Massachusetts  2169       0         100      F
# 4403    MA  Massachusetts  2370       0         135      F
# ...    ...            ...   ...     ...         ...    ...
# 1522    MA  Massachusetts  1760   74100         300      G
# 1006    MA  Massachusetts  2019   86450         350      G
# 2494    MA  Massachusetts  2125   88920         360      G
# 4147    MA  Massachusetts  2356   98800         400      G
# 3812    MA  Massachusetts  2150  345800        1400      I
#
# [4644 rows x 9 columns]

# %%
df2.sort_values(by = 'Sales',ascending = False, inplace = True) #to make it permanent, inplace = True
df2
# Out:
#                              Name                    Address          City  \
# 3812     JOHNNIE'S FOODMASTER INC       100 EVERETT AVE # 12       CHELSEA
# 4147                   ROCHE BROS  20 ROCHE BROTHERS WAY # 1  NORTH EASTON
# 2494            SUPER STOP & SHOP          8 ALLSTATE RD # B    DORCHESTER
# 1006                MARKET BASKET           274 HARTFORD AVE    BELLINGHAM
# 1660            SUPER STOP & SHOP            700 PLEASANT ST     WATERTOWN
# ...                           ...                        ...           ...
# 1346   DONELAN'S SUPERMARKETS INC               236 GREAT RD     LITTLETON
# 1340             CONCORD TEACAKES            50 BEHARRELL ST       CONCORD
# 3890       TRUCCHI'S SUPERMARKETS              1062 BROADWAY       RAYNHAM
# 288   DE MOULAS SUPER MARKETS INC                875 EAST ST     TEWKSBURY
# 1063          HONEY DEW ASSOC INC           2 TAUNTON ST # 3    PLAINVILLE
#
#      State     State_name   Zip   Sales  Number_emp Empsiz
# 3812    MA  Massachusetts  2150  345800        1400      I
# 4147    MA  Massachusetts  2356   98800         400      G
# 2494    MA  Massachusetts  2125   88920         360      G
# 1006    MA  Massachusetts  2019   86450         350      G
# 1660    MA  Massachusetts  2472   74100         300      G
# ...    ...            ...   ...     ...         ...    ...
# 1346    MA  Massachusetts  1460       0         100      F
# 1340    MA  Massachusetts  1742       0          10      C
# 3890    MA  Massachusetts  2767       0          33      D
# 288     MA  Massachusetts  1876       0         300      G
# 1063    MA  Massachusetts  2762       0          15      C
#
# [4644 rows x 9 columns]

# %%
#we can sort by more than one column
df2.sort_values(['Sales','Number_emp'], ascending = [False, True], inplace = True)
df2
# Out:
#                              Name                    Address  \
# 3812     JOHNNIE'S FOODMASTER INC       100 EVERETT AVE # 12
# 4147                   ROCHE BROS  20 ROCHE BROTHERS WAY # 1
# 2494            SUPER STOP & SHOP          8 ALLSTATE RD # B
# 1006                MARKET BASKET           274 HARTFORD AVE
# 1660            SUPER STOP & SHOP            700 PLEASANT ST
# ...                           ...                        ...
# 4060           DUNKIN' DONUTS INC              130 ROYALL ST
# 288   DE MOULAS SUPER MARKETS INC                875 EAST ST
# 1138         CUMBERLAND FARMS INC          100 CROSSING BLVD
# 3935      SHAW'S SUPERMARKETS INC            750 W CENTER ST
# 3646   STOP & SHOP SUPERMARKET CO            1385 HANCOCK ST
#
#                   City State     State_name   Zip   Sales  Number_emp Empsiz
# 3812           CHELSEA    MA  Massachusetts  2150  345800        1400      I
# 4147      NORTH EASTON    MA  Massachusetts  2356   98800         400      G
# 2494        DORCHESTER    MA  Massachusetts  2125   88920         360      G
# 1006        BELLINGHAM    MA  Massachusetts  2019   86450         350      G
# 1660         WATERTOWN    MA  Massachusetts  2472   74100         300      G
# ...                ...   ...            ...   ...     ...         ...    ...
# 4060            CANTON    MA  Massachusetts  2021       0         300      G
# 288          TEWKSBURY    MA  Massachusetts  1876       0         300      G
# 1138        FRAMINGHAM    MA  Massachusetts  1702       0         400      G
# 3935  WEST BRIDGEWATER    MA  Massachusetts  2379       0         500      H
# 3646            QUINCY    MA  Massachusetts  2169       0        1000      I
#
# [4644 rows x 9 columns]

# %% [markdown]
# ### In-class activity 3
# ### Use the resulting DataFrame df to perform the following operations:
# 1. Sort the DataFrame by descending order of CO2_emissions.
# 2. Sort the DataFrame in chronological order.
#
#
#
# ### Please, use cells below to write and execute your code. Feel free to add additional cells.
# ### Submit the resulting .ipynb file with all three in-class activities to Canvas. Don’t forget to enter your name.

# %%
# write your code for in-class activity 3 here 

df.sort_values(by = ["CO2_emissions"], ascending = False)
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions  \
# 22642       14649  2017      3   29        96       5         0.1440
# 17077        1383  2016      2   27        92       5         0.1380
# 14183       14368  2017      2   23        92       5         0.1380
# 2874         1817  2016      1    9        92       5         0.1380
# 1085         1315  2016      1    5        91       5         0.1365
# ...           ...   ...    ...  ...       ...     ...            ...
# 5034        14467  2016      1   16        28      10         0.0196
# 16923        1054  2017      3    7        24       9         0.0192
# 18048        1326  2016      3    2        27      10         0.0189
# 16127        1531  2017      3    3        26      10         0.0182
# 21766        1287  2016      3   15        25      10         0.0175
#
#        CO2_per_day
# 22642      69.1200
# 17077      63.4800
# 14183      63.4800
# 2874       63.4800
# 1085       62.1075
# ...            ...
# 5034        5.4880
# 16923       4.1472
# 18048       5.1030
# 16127       4.7320
# 21766       4.3750
#
# [49182 rows x 8 columns]

# %%
df.sort_values(by = ["Year",'Month','Day'])
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions  \
# 0           14620  2016      1    1        47      10         0.0329
# 1             693  2016      1    2        63       9         0.0504
# 2             695  2016      1    2        53       9         0.0424
# 3             705  2016      1    2        58       7         0.0638
# 4             811  2016      1    2        64       5         0.0960
# ...           ...   ...    ...  ...       ...     ...            ...
# 23231       14711  2017      3   31        58       8         0.0522
# 23232       14750  2017      3   31        68       6         0.0884
# 23233       14772  2017      3   31        62       5         0.0930
# 23234       14778  2017      3   31        73      10         0.0511
# 23235       14779  2017      3   31        66       5         0.0990
#
#        CO2_per_day       Date
# 0          15.4630 2016-01-01
# 1          28.5768 2016-01-02
# 2          20.2248 2016-01-02
# 3          25.9028 2016-01-02
# 4          30.7200 2016-01-02
# ...            ...        ...
# 23231      24.2208 2017-03-31
# 23232      36.0672 2017-03-31
# 23233      28.8300 2017-03-31
# 23234      37.3030 2017-03-31
# 23235      32.6700 2017-03-31
#
# [49182 rows x 9 columns]

# %%
#Checking results
df['Date'] = pd.to_datetime(df[['Year','Month','Day']])
df.sort_values(by=['Date'])
# Out:
#        Vehicle_ID  Year  Month  Day  Distance  Weight  CO2_emissions  \
# 0           14620  2016      1    1        47      10         0.0329
# 266          1780  2016      1    2        58       8         0.0522
# 265          1779  2016      1    2        53       7         0.0583
# 264          1767  2016      1    2        64       9         0.0512
# 263          1767  2016      1    2        69       8         0.0621
# ...           ...   ...    ...  ...       ...     ...            ...
# 23047        1460  2017      3   31        66       8         0.0594
# 23046        1459  2017      3   31        55       6         0.0715
# 23045        1458  2017      3   31        54       5         0.0810
# 23051        1466  2017      3   31        73       8         0.0657
# 23235       14779  2017      3   31        66       5         0.0990
#
#        CO2_per_day       Date
# 0          15.4630 2016-01-01
# 266        24.2208 2016-01-02
# 265        21.6293 2016-01-02
# 264        29.4912 2016-01-02
# 263        34.2792 2016-01-02
# ...            ...        ...
# 23047      31.3632 2017-03-31
# 23046      23.5950 2017-03-31
# 23045      21.8700 2017-03-31
# 23051      38.3688 2017-03-31
# 23235      32.6700 2017-03-31
#
# [49182 rows x 9 columns]

# %% [markdown]
# # Plotting, this is not on the test

# %%
df2['Sales'].hist()
# Out:
# <AxesSubplot: >

# %%
#we can filter out

df2[df2['Sales']<5000]['Sales'].hist()
# Out:
# <AxesSubplot: >

# %%
df2[df2['Sales']<5000].plot.scatter(x='Sales',y='Number_emp')
# Out:
# c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Sales', ylabel='Number_emp'>

# %%
#we need to filter number of emp
df2[(df2['Sales']<5000) & (df2['Number_emp']<50)].plot.scatter(x='Sales',y='Number_emp')
# Out:
# c:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Sales', ylabel='Number_emp'>

# %%
# lets look at the correlation
df2[(df2['Sales']<5000) & (df2['Number_emp']<50)][['Sales','Number_emp']].corr()
# Out:
#                Sales  Number_emp
# Sales       1.000000    0.593296
# Number_emp  0.593296    1.000000
